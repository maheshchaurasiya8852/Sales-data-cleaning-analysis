# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\mahes\appdata\local\programs\python\python312\lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mahes\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mahes\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\mahes\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2026.4)
# Requirement already satisfied: six>=1.5 in c:\users\mahes\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/sales.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("../data/sales.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/sales.csv'

# %%
df = pd.read_csv("Desktop/sales-data-cleaning-analysis/data/sales.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv("Desktop/sales-data-cleaning-analysis/data/sales.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/sales-data-cleaning-analysis/data/sales.csv'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mahes\\Desktop\\sales-data-cleaning-analysis\\notebooks'

# %%
df = pd.read_csv("../data/sales.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_csv("../data/sales.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/sales.csv'

# %%
import os
os.listdir("../data")
# Out:
# ['sales.csv.txt']

# %%
os.listdir("../data")
# Out:
# ['sales.csv.txt']

# %%
df = pd.read_csv("../data/sales.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_csv("../data/sales.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/sales.csv'

# %%
import os
os.listdir("../data")
# Out:
# ['sales.csv.txt']

# %%
os.listdir("../data")
# Out:
# ['sales.csv.txt']

# %%
df = pd.read_csv("../data/sales.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.read_csv("../data/sales.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/sales.csv'

# %%
import os
print(os.path.abspath("../data"))
print(os.listdir("../data"))
# Out:
# C:\Users\mahes\Desktop\sales-data-cleaning-analysis\data
# ['sales.csv.txt']

# %%
os.listdir("../data")
# Out:
# ['sales.csv']

# %%
df = pd.read_csv("../data/sales.csv")

# %%
df
# Out:
#           Date   Product Region    Sales  Quantity
# 0   2025-01-01    Laptop  North  50000.0       2.0
# 1   2025-01-02     Mouse  South   1000.0       5.0
# 2   2025-01-03  Keyboard   East   2000.0       3.0
# 3   2025-01-04    Laptop  North  50000.0       2.0
# 4   2025-01-05     Mouse  SOUTH   1000.0       5.0
# 5   2025-01-06   Monitor   West  15000.0       1.0
# 6   2025-01-07  Keyboard   East      NaN       4.0
# 7   2025-01-08    Laptop  North  55000.0       2.0
# 8   2025-01-09     Mouse  South   1000.0       NaN
# 9   2025-01-10   Monitor   West  15000.0       1.0
# 10  2025-01-10   Monitor   West  15000.0       1.0
# 11  2025-01-11  Keyboard   east   2000.0       3.0
# 12  2025-01-12    Laptop  North  60000.0       2.0

# %%
df.head()
# Out:
#          Date   Product Region    Sales  Quantity
# 0  2025-01-01    Laptop  North  50000.0       2.0
# 1  2025-01-02     Mouse  South   1000.0       5.0
# 2  2025-01-03  Keyboard   East   2000.0       3.0
# 3  2025-01-04    Laptop  North  50000.0       2.0
# 4  2025-01-05     Mouse  SOUTH   1000.0       5.0

# %%
df.shape
# Out:
# (13, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      13 non-null     str
#  1   Product   13 non-null     str
#  2   Region    13 non-null     str
#  3   Sales     12 non-null     float64
#  4   Quantity  12 non-null     float64
# dtypes: float64(2), str(3)
# memory usage: 652.0 bytes

# %%
df = pd.read_csv("../data/sales.csv")

# %%
df
# Out:
#           Date   Product Region    Sales  Quantity
# 0   2025-01-01    Laptop  North  50000.0       2.0
# 1   2025-01-02     Mouse  South   1000.0       5.0
# 2   2025-01-03  Keyboard   East   2000.0       3.0
# 3   2025-01-04    Laptop  North  50000.0       2.0
# 4   2025-01-05     Mouse  SOUTH   1000.0       5.0
# 5   2025-01-06   Monitor   West  15000.0       1.0
# 6   2025-01-07  Keyboard   East      NaN       4.0
# 7   2025-01-08    Laptop  North  55000.0       2.0
# 8   2025-01-09     Mouse  South   1000.0       NaN
# 9   2025-01-10   Monitor   West  15000.0       1.0
# 10  2025-01-10   Monitor   West  15000.0       1.0
# 11  2025-01-11  Keyboard   east   2000.0       3.0
# 12  2025-01-12    Laptop  North  60000.0       2.0

# %%
df.head()
# Out:
#          Date   Product Region    Sales  Quantity
# 0  2025-01-01    Laptop  North  50000.0       2.0
# 1  2025-01-02     Mouse  South   1000.0       5.0
# 2  2025-01-03  Keyboard   East   2000.0       3.0
# 3  2025-01-04    Laptop  North  50000.0       2.0
# 4  2025-01-05     Mouse  SOUTH   1000.0       5.0

# %%
df.shape
# Out:
# (13, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      13 non-null     str
#  1   Product   13 non-null     str
#  2   Region    13 non-null     str
#  3   Sales     12 non-null     float64
#  4   Quantity  12 non-null     float64
# dtypes: float64(2), str(3)
# memory usage: 652.0 bytes

# %%
df = pd.read_csv("../data/sales.csv")

# %%
df.head()
# Out:
#          Date   Product Region    Sales  Quantity
# 0  2025-01-01    Laptop  North  50000.0       2.0
# 1  2025-01-02     Mouse  South   1000.0       5.0
# 2  2025-01-03  Keyboard   East   2000.0       3.0
# 3  2025-01-04    Laptop  North  50000.0       2.0
# 4  2025-01-05     Mouse  SOUTH   1000.0       5.0

# %%
df.shape
# Out:
# (13, 5)

# %%
df.columns
# Out:
# Index(['Date', 'Product', 'Region', 'Sales', 'Quantity'], dtype='str')

# %%
df.isnull().sum()
# Out:
# Date        0
# Product     0
# Region      0
# Sales       1
# Quantity    1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.head()
# Out:
#          Date   Product Region    Sales  Quantity
# 0  2025-01-01    Laptop  North  50000.0       2.0
# 1  2025-01-02     Mouse  South   1000.0       5.0
# 2  2025-01-03  Keyboard   East   2000.0       3.0
# 3  2025-01-04    Laptop  North  50000.0       2.0
# 4  2025-01-05     Mouse  SOUTH   1000.0       5.0

# %%
df.shape
# Out:
# (13, 5)

# %%
df.columns
# Out:
# Index(['Date', 'Product', 'Region', 'Sales', 'Quantity'], dtype='str')

# %%
df.isnull().sum()
# Out:
# Date        0
# Product     0
# Region      0
# Sales       1
# Quantity    1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#           Date  Product Region    Sales  Quantity
# 10  2025-01-10  Monitor   West  15000.0       1.0

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Date        0
# Product     0
# Region      0
# Sales       1
# Quantity    1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date        0
# Product     0
# Region      0
# Sales       1
# Quantity    1
# dtype: int64

# %%
df[df["Sales"].isnull()]
# Out:
#          Date   Product Region  Sales  Quantity
# 6  2025-01-07  Keyboard   East    NaN       4.0

# %%
df[df["Quantity"].isnull()]
# Out:
#          Date Product Region   Sales  Quantity
# 8  2025-01-09   Mouse  South  1000.0       NaN

# %%
df.loc[df["Quantity"].isnull(), "Quantity"] = 5

# %%
df.isnull().sum()
# Out:
# Date        0
# Product     0
# Region      0
# Sales       1
# Quantity    0
# dtype: int64

# %%
df[df["Sales"].isnull()]
# Out:
#          Date   Product Region  Sales  Quantity
# 6  2025-01-07  Keyboard   East    NaN       4.0

# %%
df[df["Product"] == "Keyboard"]
# Out:
#           Date   Product Region   Sales  Quantity
# 2   2025-01-03  Keyboard   East  2000.0       3.0
# 6   2025-01-07  Keyboard   East     NaN       4.0
# 11  2025-01-11  Keyboard   east  2000.0       3.0

# %%
df["Sales"] = df["Sales"].fillna(df["Sales"].median())

# %%
df.isnull().sum()
# Out:
# Date        0
# Product     0
# Region      0
# Sales       0
# Quantity    0
# dtype: int64

# %%
df["Region"] = df["Region"].str.strip().str.title()

# %%
df["Region"].unique()
# Out:
# <StringArray>
# ['North', 'South', 'East', 'West']
# Length: 4, dtype: str

# %%
df.dtypes
# Out:
# Date            str
# Product         str
# Region          str
# Sales       float64
# Quantity    float64
# dtype: object

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Date        datetime64[us]
# Product                str
# Region                 str
# Sales              float64
# Quantity           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date        0
# Product     0
# Region      0
# Sales       0
# Quantity    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Date        0
# Product     0
# Region      0
# Sales       0
# Quantity    0
# dtype: int64

# %%
df.dtypes
# Out:
# Date        datetime64[us]
# Product                str
# Region                 str
# Sales              float64
# Quantity           float64
# dtype: object

# %%
df["Sales"].sum()
# Out:
# np.float64(267000.0)

# %%
df["Sales"].mean()
# Out:
# np.float64(22250.0)

# %%
df.groupby("Product")["Sales"].sum()
# Out:
# Product
# Keyboard     19000.0
# Laptop      215000.0
# Monitor      30000.0
# Mouse         3000.0
# Name: Sales, dtype: float64

# %%
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# East      19000.0
# North    215000.0
# South      3000.0
# West      30000.0
# Name: Sales, dtype: float64

# %%
df.groupby("Product")["Quantity"].sum()
# Out:
# Product
# Keyboard    10.0
# Laptop       8.0
# Monitor      2.0
# Mouse       15.0
# Name: Quantity, dtype: float64

# %%
df.groupby(["Region", "Product"])["Sales"].sum()
# Out:
# Region  Product
# East    Keyboard     19000.0
# North   Laptop      215000.0
# South   Mouse         3000.0
# West    Monitor      30000.0
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

product_sales = df.groupby("Product")["Sales"].sum()

product_sales.plot(kind="bar")

plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2
#       3 product_sales = df.groupby("Product")["Sales"].sum()
#       4
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.2-cp312-cp312-win_amd64.whl.metadata (80 kB)
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      -------------- ------------------------ 30.7/80.3 kB 81.9 kB/s eta 0:00:01
#      -------------- ------------------------ 30.7/80.3 kB 81.9 kB/s eta 0:00:01
#      ------------------- ------------------- 41.0/80.3 kB 98.5 kB/s eta 0:00:01
#      -------------------------------------- 80.3/80.3 kB 172.5 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.4.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4
#    ------------------------------------ --- 6.7/7.2 MB 438.2 kB/s eta 0:00:02
#    ------------------------------------ --- 6.7/7.2 MB 437.6 kB/s eta 0:00:02
#    ------------------------------------- -- 6.7/7.2 MB 437.6 kB/s eta 0:00:02
#    ------------------------------------- -- 6.7/7.2 MB 437.6 kB/s eta 0:00:02
#    ------------------------------------- -- 6.7/7.2 MB 437.6 kB/s eta 0:00:02
#    ------------------------------------- -- 6.7/7.2 MB 437.6 kB/s eta 0:00:02
#    ------------------------------------- -- 6.8/7.2 MB 441.1 kB/s eta 0:00:01
#    ------------------------------------- -- 6.9/7.2 MB 441.1 kB/s eta 0:00:01
#    -------------------------------------- - 6.9/7.2 MB 442.2 kB/s eta 0:00:01
#    -------------------------------------- - 6.9/7.2 MB 442.8 kB/s eta 0:00:01
#    -------------------------------------- - 6.9/7.2 MB 442.3 kB/s eta 0:00:01
#    -------------------------------------- - 7.0/7.2 MB 443.0 kB/s eta 0:00:01
#    -------------------------------------- - 7.0/7.2 MB 443.0 kB/s eta 0:00:01
#    -------------------------------------- - 7.0/7.2 MB 443.2 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 444.2 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 445.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 446.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 446.1 kB/s eta 0:00:01
#    ---------------------------------------  7.2/7.2 MB 446.0 kB/s eta 0:00:01
#    ---------------------------------------  7.2/7.2 MB 447.9 kB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 447.1 kB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.8 kB ? eta -:--:--
#    ---------- ----------------------------- 30.7/122.8 kB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 61.4/122.8 kB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------ 81.9/122.8 kB 762.6 kB/s eta 0:00:01
#    ---------------------------------- --- 112.6/122.8 kB 731.4 kB/s eta 0:00:01
#    -------------------------------------- 122.8/122.8 kB 601.8 kB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.4.0 cycler-0.12.1 fonttools-4.65.0 kiwisolver-1.5.1 matplotlib-3.11.2 pillow-12.3.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt

product_sales = df.groupby("Product")["Sales"].sum()

product_sales.plot(kind="bar")

plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
region_sales = df.groupby("Region")["Sales"].sum()

region_sales.plot(kind="bar")

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
quantity_product = df.groupby("Product")["Quantity"].sum()

quantity_product.plot(kind="bar")

plt.title("Quantity Sold by Product")
plt.xlabel("Product")
plt.ylabel("Quantity")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
